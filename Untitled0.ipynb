# %% [markdown]
# <a href="https://colab.research.google.com/github/nikhilraju335/pythonlab/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#find the greatest of three numbers
a=int(input("enter first number"))
b=int(input("enter second number"))
c=int(input("enter third number"))
if a>b and a>c :
  print(f"{a} is bigger")
elif b>a and b>c:
  print(f"{b} is bigger")
else:
  print(f"{c} is bigger")
# Out:
# enter first number4
# enter second number45
# enter third number5
# 45 is bigger

# %%
a=int(input())
b=int(input())
print(a,b)
a,b=b,a
print(a,b)
# Out:
# 14
# 45
# 14 45
# 45 14

# %%
a=int(input())
b=int(input())
c=complex(a,b)
print(c)
# Out:
# 2
# 34
# (2+34j)

# %%
n=int(input("enter number of elements"))
i=0
while i<n :
  print(i)
  i=i+1
# Out:
# enter number of elements5
# 0
# 1
# 2
# 3
# 4

# %%
import numpy as np
import pandas as pd
