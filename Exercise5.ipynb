# %% [markdown]
# <a href="https://colab.research.google.com/github/nikhilraju335/pythonlab/blob/main/Exercise5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1.split
a="nikhil raju"
print(a.split())
# Out:
# ['nikhil', 'raju']

# %%
#2.join
a=["nikjil","raju"]
b="".join(a)
print(b)
# Out:
# nikjilraju

# %%
#upper and lower
a="nikhil"
print(a.upper())
print(a.lower())
# Out:
# NIKHIL
# nikhil

# %%
#strip
a="nikhil"
print(a.strip())
# Out:
# nikhil

# %%
#replace
a="salaar"
print(a.replace("salaar","OG"))
# Out:
# OG

# %%
#count of vowels and consonats
a=input()
vowels=0
consonats=0
a=a.replace(" ","")
for i in a:
  if i in 'aeiouAEIOU':
    vowels+=1
  else:
    consonats+=1
print(vowels)
print(consonats)
# Out:
# nikhilk rzafdvbn
# 3
# 12

# %%
#program that checks the sunstring in the original string if yes print the index of substring
a=input("enter the given string")
A=input("enter the substring")
if A in a:
  print(a.find(A))
else:
  print("STRING IS NOT FOUND")
# Out:
# enter the given stringNIKHIL RAJU
# enter the substringRAJU
# 7
