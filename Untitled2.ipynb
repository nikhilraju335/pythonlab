# %% [markdown]
# <a href="https://colab.research.google.com/github/nikhilraju335/pythonlab/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=[1,2,3,4]
print(a[0])
print(a[1])
# Out:
# 1
# 2

# %%
a=[1,3,45,7,76,64,43,7,43]
print(a[-1])
print(a[1:3])
print(a[:4])
print(a[1:5:2])
print(a[:7:2])
# Out:
# 43
# [3, 45]
# [1, 3, 45, 7]
# [3, 7]
# [1, 45, 76, 43]

# %%
a=[1,3,566,78,89,8]
b=[4,5]
print(a+b)
# Out:
# [1, 3, 566, 78, 89, 8, 4, 5]

# %%
a=[1,2]
print(a*2)
# Out:
# [1, 2, 1, 2]

# %%
a=[1,3,4]
a.append(5)
print(a)
# Out:
# [1, 3, 4, 5]

# %%
a=[1,3,34]
a.reverse()
print(a)
# Out:
# [34, 3, 1]

# %%
a=[1,23,5,67,7]
a.sort()
print(a)
# Out:
# [1, 5, 7, 23, 67]

# %%
a=[1,2,4,56]
a.extend([8,9])
print(a)
# Out:
# [1, 2, 4, 56, 8, 9]

# %%
a=[1,23,45,6,7]
print(len(a))
print(max(a))
print(min(a))
print(sum(a))
# Out:
# 5
# 45
# 1
# 82

# %%
a=[1,1,2,2,2,3,3,3,33,3,3,3]

print(a.count(3))
# Out:
# 6

# %%
a=[1,3,5,7,8,5,2,2,6]
a.pop(3)
print(a)
# Out:
# [1, 3, 5, 8, 5, 2, 2, 6]

# %%
a=[1,2,3,4,45]
a.remove(45)

print(a)
# Out:
# [1, 2, 3, 4]

# %%
a=[1,3,4,5,6]
a.insert(2,66)
print(a)
# Out:
# [1, 3, 66, 4, 5, 6]

# %%
a=[1,3,3,45]
a.clear()
print(a)
# Out:
# []
