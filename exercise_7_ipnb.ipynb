# %% [markdown]
# <a href="https://colab.research.google.com/github/nikhilraju335/pythonlab/blob/main/exercise_7_ipnb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#tuples
t=()
print(type(t))
# Out:
# <class 'tuple'>

# %%
#indexing
t=(10,20,30)
print(t[0]);
# Out:
# 10

# %%
#sum
a=(354,6)
print(sum(a))
# Out:
# 360

# %%
#concententation
a=(1,2,3)
b=(55,5,6)
print(a+b)
# Out:
# (1, 2, 3, 55, 5, 6)

# %%
#length
t=(1,34,5,742,2)
print(len(t))
# Out:
# 5

# %%
#max
t=(1,2,3,66,76,67)
print(max(t))
# Out:
# 76

# %%
#min
t=(1,2,43,56,5)
print(min(t))
# Out:
# 1

# %%
#repetition
t=(1,2,3,43)
print(t*2)
# Out:
# (1, 2, 3, 43, 1, 2, 3, 43)

# %%
#methods
t=(1,3,334,4)
print(t.count(4))
print(t.index(334))
# Out:
# 1
# 2

# %%
t=("nikhil",19,"komallapudi","vishnu")
t1=("pavan naidu",20,"razole","vishnu");
print(t+t1)
# Out:
# ('nikhil', 19, 'komallapudi', 'vishnu', 'pavan naidu', 20, 'razole', 'vishnu')

# %%
a=input("enter the given string")
b=a.lower()
c=b.count('a')+b.count('e')+b.count('i')+b.count('o')+b.count('u')
print(c)
# Out:
# enter the given stringpavan naidu
# 5

# %%
########################################################### SETS   ##################################################################################
a=set()
print(type(a))
# Out:
# <class 'set'>

# %%
a={10,20,30}

a.update([30,50])
print(a)
# Out:
# {10, 20, 50, 30}
